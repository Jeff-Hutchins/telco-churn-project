# %%
import pandas as pd
import numpy as np
import scipy as sp 
import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib inline
# ignore warnings
import warnings
warnings.filterwarnings("ignore")

from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, MinMaxScaler

import env
import acquire
import prepare2

# %%
df = acquire.get_telco_churn_data()
df.head()
# Out:
#   customer_id  gender  senior_citizen partner dependents  tenure  \
# 0  0002-ORFBO  Female               0     Yes        Yes       9
# 1  0003-MKNFE    Male               0      No         No       9
# 2  0004-TLHLJ    Male               0      No         No       4
# 3  0011-IGKFF    Male               1     Yes         No      13
# 4  0013-EXCHZ  Female               1     Yes         No       3
#
#   phone_service multiple_lines  internet_service_type_id online_security  ...  \
# 0           Yes             No                         1              No  ...
# 1           Yes            Yes                         1              No  ...
# 2           Yes             No                         2              No  ...
# 3           Yes             No                         2              No  ...
# 4           Yes             No                         2              No  ...
#
#   device_protection tech_support streaming_tv streaming_movies  \
# 0                No          Yes          Yes               No
# 1                No           No           No              Yes
# 2               Yes           No           No               No
# 3               Yes           No          Yes              Yes
# 4                No          Yes          Yes               No
#
#   contract_type_id  paperless_billing payment_type_id  monthly_charges  \
# 0                2                Yes               2             65.6
# 1                1                 No               2             59.9
# 2                1                Yes               1             73.9
# 3                1                Yes               1             98.0
# 4                1                Yes               2             83.9
#
#    total_charges churn
# 0          593.3    No
# 1          542.4    No
# 2         280.85   Yes
# 3        1237.85   Yes
# 4          267.4   Yes
#
# [5 rows x 21 columns]

# %%
df = prepare2.prepare(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-da67f35b3263> in <module>
# ----> 1 df = prepare2.prepare(df)
#
# ~/codeup-data-science/telco-churn-project/prepare2.py in prepare(df)
#     136
#     137 def prepare(df):
# --> 138     df=df.pipe(clean_data).pipe(combine_and_clean_variables).pipe(encode1).pipe(encode2).pipe(scale_minmax).pipe(split_data)
#     139     return df
#     140
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in pipe(self, func, *args, **kwargs)
#    4919     @Appender(_shared_docs['pipe'] % _shared_doc_kwargs)
#    4920     def pipe(self, func, *args, **kwargs):
# -> 4921         return com._pipe(self, func, *args, **kwargs)
#    4922
#    4923     _shared_docs['aggregate'] = dedent("""
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/common.py in _pipe(obj, func, *args, **kwargs)
#     452         return func(*args, **kwargs)
#     453     else:
# --> 454         return func(obj, *args, **kwargs)
#     455
#     456
#
# ~/codeup-data-science/telco-churn-project/prepare2.py in encode1(df, col_name)
#      61
#      62     # create 2D np arrays of the encoded variable (in train and test)
# ---> 63     df_array = np.array(df.encoded).reshape(len(df.encoded),1)
#      64
#      65     # One Hot Encoding
#
# AttributeError: 'numpy.ndarray' object has no attribute 'encoded'

# %%
df.head()
# Out:
#   customer_id  gender  senior_citizen partner dependents  tenure  \
# 0  0002-ORFBO  Female               0     Yes        Yes       9
# 1  0003-MKNFE    Male               0      No         No       9
# 2  0004-TLHLJ    Male               0      No         No       4
# 3  0011-IGKFF    Male               1     Yes         No      13
# 4  0013-EXCHZ  Female               1     Yes         No       3
#
#   phone_service multiple_lines  internet_service_type_id online_security  ...  \
# 0           Yes             No                         1              No  ...
# 1           Yes            Yes                         1              No  ...
# 2           Yes             No                         2              No  ...
# 3           Yes             No                         2              No  ...
# 4           Yes             No                         2              No  ...
#
#   device_protection tech_support streaming_tv streaming_movies  \
# 0                No          Yes          Yes               No
# 1                No           No           No              Yes
# 2               Yes           No           No               No
# 3               Yes           No          Yes              Yes
# 4                No          Yes          Yes               No
#
#   contract_type_id  paperless_billing payment_type_id  monthly_charges  \
# 0                2                Yes               2             65.6
# 1                1                 No               2             59.9
# 2                1                Yes               1             73.9
# 3                1                Yes               1             98.0
# 4                1                Yes               2             83.9
#
#    total_charges  churn
# 0         593.30     No
# 1         542.40     No
# 2         280.85    Yes
# 3        1237.85    Yes
# 4         267.40    Yes
#
# [5 rows x 21 columns]
